# %%
import dask
import dask.dataframe as dd

# %%
from dask.distributed import LocalCluster
cluster = LocalCluster()
client = cluster.get_client()

# %%
train = dd.read_csv("data/training_set_VU_DM.csv")
imputed_train = dd.read_csv("midas_imp_1.csv")
# train["date_time"] = dd.to_datetime(train["date_time"], format= "%Y-%m-%d %H:%M:%S")

# test = dd.read_csv("data/test_set_VU_DM.csv")
# test["date_time"] = dd.to_datetime(test["date_time"], format= "%Y-%m-%d %H:%M:%S")
train.head(10)
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
# 5        1  2013-04-04 08:32:15       12                          187
# 6        1  2013-04-04 08:32:15       12                          187
# 7        1  2013-04-04 08:32:15       12                          187
# 8        1  2013-04-04 08:32:15       12                          187
# 9        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# ...

# %%
imputed_train.head(10)
# Out:
#    srch_id  site_id  visitor_location_country_id  visitor_hist_starrating  \
# 0        1       12                          187               172.635742
# 1        1       12                          187               133.736481
# 2        1       12                          187                98.238007
# 3        1       12                          187                69.213814
# 4        1       12                          187               130.796432
# 5        1       12                          187               104.523201
# 6        1       12                          187                63.918903
# 7        1       12                          187               145.065201
# 8        1       12                          187                41.634293
# 9        1       12                          187               119.038589
#
#    visitor_hist_adr_usd  prop_country_id  prop_id  prop_starrating  \
# 0            460.701660              219      893                3
# ...

# %%
stats = imputed_train.describe().compute()

# %%
stats.to_clipboard(excel=True)

# %%
stats
# Out:
#             srch_id       site_id  visitor_location_country_id  \
# count  4.958347e+06  4.958347e+06                 4.958347e+06
# mean   1.663666e+05  9.953133e+00                 1.753405e+02
# std    9.611223e+04  7.646890e+00                 6.591625e+01
# min    1.000000e+00  1.000000e+00                 1.000000e+00
# 25%    8.095700e+04  5.000000e+00                 1.030000e+02
# 50%    1.645610e+05  5.000000e+00                 2.190000e+02
# 75%    2.477710e+05  1.400000e+01                 2.190000e+02
# max    3.327850e+05  3.400000e+01                 2.310000e+02
#
#        visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  \
# count             4.958347e+06          4.958347e+06     4.958347e+06
# mean              7.398612e+01          1.902299e+02     1.739739e+02
# std               1.585420e+02          6.163675e+03     6.834525e+01
# min              -1.690415e+05         -7.768866e+06     1.000000e+00
# ...

# %%
stats.shape
# Out:
# (8, 54)
